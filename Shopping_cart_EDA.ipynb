# %% [markdown]
# # you have a data set called shopping cart it consist of four datasets
# - 1- customers.csv
# - 2- orders.csv
# - 3- products.csv
# - 4- sales.csv
# # your task in this project is:
# - 1- combine this data together
# - 2- check messing values
# - 3- show summary statistics
# - 4- deal with date time and extract features from dates
# - 5- answer at least three questions from this data

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %% [markdown]
# ## Load data

# %%
order = pd.read_csv('orders.csv')
order.head()
# Out:
#    order_id  customer_id  payment order_date delivery_date
# 0         1           64    30811  2021-8-30    2021-09-24
# 1         2          473    50490   2021-2-3    2021-02-13
# 2         3          774    46763  2021-10-8    2021-11-03
# 3         4          433    39782   2021-5-6    2021-05-19
# 4         5          441    14719  2021-3-23    2021-03-24

# %%
order.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       1000 non-null   int64
#  1   customer_id    1000 non-null   int64
#  2   payment        1000 non-null   int64
#  3   order_date     1000 non-null   object
#  4   delivery_date  1000 non-null   object
# dtypes: int64(3), object(2)
# memory usage: 39.2+ KB

# %%
customer = pd.read_csv('/content/customers.csv')
customer.head()
# Out:
#    customer_id        customer_name       gender  age  \
# 0            1        Leanna Busson       Female   30
# 1            2  Zabrina Harrowsmith  Genderfluid   69
# 2            3      Shina Dullaghan   Polygender   59
# 3            4        Hewet McVitie     Bigender   67
# 4            5       Rubia Ashleigh   Polygender   30
#
#                      home_address  zip_code               city  \
# 0  8606 Victoria TerraceSuite 560      5464      Johnstonhaven
# 1      8327 Kirlin SummitApt. 461      8223    New Zacharyfort
# 2       269 Gemma SummitSuite 109      5661           Aliburgh
# 3       743 Bailey GroveSuite 141      1729  South Justinhaven
# 4         48 Hyatt ManorSuite 375      4032     Griffithsshire
#
#                           state    country
# 0            Northern Territory  Australia
# 1               South Australia  Australia
# 2  Australian Capital Territory  Australia
# 3                    Queensland  Australia
# 4                    Queensland  Australia

# %%
customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customer_id    1000 non-null   int64
#  1   customer_name  1000 non-null   object
#  2   gender         1000 non-null   object
#  3   age            1000 non-null   int64
#  4   home_address   1000 non-null   object
#  5   zip_code       1000 non-null   int64
#  6   city           1000 non-null   object
#  7   state          1000 non-null   object
#  8   country        1000 non-null   object
# dtypes: int64(3), object(6)
# memory usage: 70.4+ KB

# %%
product = pd.read_csv('/content/products.csv')
product.head()
# Out:
#    product_ID product_type  product_name size colour  price  quantity  \
# 0           0        Shirt  Oxford Cloth   XS    red    114        66
# 1           1        Shirt  Oxford Cloth    S    red    114        53
# 2           2        Shirt  Oxford Cloth    M    red    114        54
# 3           3        Shirt  Oxford Cloth    L    red    114        69
# 4           4        Shirt  Oxford Cloth   XL    red    114        47
#
#                                     description
# 0  A red coloured, XS sized, Oxford Cloth Shirt
# 1   A red coloured, S sized, Oxford Cloth Shirt
# 2   A red coloured, M sized, Oxford Cloth Shirt
# 3   A red coloured, L sized, Oxford Cloth Shirt
# 4  A red coloured, XL sized, Oxford Cloth Shirt

# %%
product.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1260 entries, 0 to 1259
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product_ID    1260 non-null   int64
#  1   product_type  1260 non-null   object
#  2   product_name  1260 non-null   object
#  3   size          1260 non-null   object
#  4   colour        1260 non-null   object
#  5   price         1260 non-null   int64
#  6   quantity      1260 non-null   int64
#  7   description   1260 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 78.9+ KB

# %%
sales = pd.read_csv('/content/sales.csv')
sales.head()
# Out:
#    sales_id  order_id  product_id  price_per_unit  quantity  total_price
# 0         0         1         218             106         2          212
# 1         1         1         481             118         1          118
# 2         2         1           2              96         3          288
# 3         3         1        1002             106         2          212
# 4         4         1         691             113         3          339

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sales_id        5000 non-null   int64
#  1   order_id        5000 non-null   int64
#  2   product_id      5000 non-null   int64
#  3   price_per_unit  5000 non-null   int64
#  4   quantity        5000 non-null   int64
#  5   total_price     5000 non-null   int64
# dtypes: int64(6)
# memory usage: 234.5 KB

# %% [markdown]
# ## Merge the data

# %%
df_merged = pd.merge(order, customer, on='customer_id')

# %%
df_merged.head()
# Out:
#    order_id  customer_id  payment order_date delivery_date     customer_name  \
# 0         1           64    30811  2021-8-30    2021-09-24  Annabella Devote
# 1         2          473    50490   2021-2-3    2021-02-13       Lori Briars
# 2       221          473    49366   2021-8-3    2021-08-17       Lori Briars
# 3         3          774    46763  2021-10-8    2021-11-03      Ellynn Korba
# 4       353          774    46198  2021-3-30    2021-04-05      Ellynn Korba
#
#         gender  age                   home_address  zip_code  \
# 0  Genderfluid   75      4927 Alice MeadowApt. 960      7787
# 1         Male   61  531 Schmitt BoulevardApt. 010      1744
# 2         Male   61  531 Schmitt BoulevardApt. 010      1744
# 3  Genderqueer   34       2096 Wilson MewsApt. 714      8590
# 4  Genderqueer   34       2096 Wilson MewsApt. 714      8590
#
#                  city            state    country
# 0      Sanfordborough  South Australia  Australia
# 1             Annaton  South Australia  Australia
# 2             Annaton  South Australia  Australia
# 3  West Jonathanshire         Tasmania  Australia
# 4  West Jonathanshire         Tasmania  Australia

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       1000 non-null   int64
#  1   customer_id    1000 non-null   int64
#  2   payment        1000 non-null   int64
#  3   order_date     1000 non-null   object
#  4   delivery_date  1000 non-null   object
#  5   customer_name  1000 non-null   object
#  6   gender         1000 non-null   object
#  7   age            1000 non-null   int64
#  8   home_address   1000 non-null   object
#  9   zip_code       1000 non-null   int64
#  10  city           1000 non-null   object
#  11  state          1000 non-null   object
#  12  country        1000 non-null   object
# dtypes: int64(5), object(8)
# memory usage: 109.4+ KB

# %%
df_merged_1 = pd.merge(df_merged, sales, on='order_id')

# %%
df_merged_1.head()
# Out:
#    order_id  customer_id  payment order_date delivery_date     customer_name  \
# 0         1           64    30811  2021-8-30    2021-09-24  Annabella Devote
# 1         1           64    30811  2021-8-30    2021-09-24  Annabella Devote
# 2         1           64    30811  2021-8-30    2021-09-24  Annabella Devote
# 3         1           64    30811  2021-8-30    2021-09-24  Annabella Devote
# 4         1           64    30811  2021-8-30    2021-09-24  Annabella Devote
#
#         gender  age               home_address  zip_code            city  \
# 0  Genderfluid   75  4927 Alice MeadowApt. 960      7787  Sanfordborough
# 1  Genderfluid   75  4927 Alice MeadowApt. 960      7787  Sanfordborough
# 2  Genderfluid   75  4927 Alice MeadowApt. 960      7787  Sanfordborough
# 3  Genderfluid   75  4927 Alice MeadowApt. 960      7787  Sanfordborough
# 4  Genderfluid   75  4927 Alice MeadowApt. 960      7787  Sanfordborough
#
#              state    country  sales_id  product_id  price_per_unit  quantity  \
# 0  South Australia  Australia         0         218             106         2
# 1  South Australia  Australia         1         481             118         1
# 2  South Australia  Australia         2           2              96         3
# 3  South Australia  Australia         3        1002             106         2
# 4  South Australia  Australia         4         691             113         3
#
#    total_price
# 0          212
# 1          118
# 2          288
# 3          212
# 4          339

# %%
df_merged_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5000 entries, 0 to 4999
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        5000 non-null   int64
#  1   customer_id     5000 non-null   int64
#  2   payment         5000 non-null   int64
#  3   order_date      5000 non-null   object
#  4   delivery_date   5000 non-null   object
#  5   customer_name   5000 non-null   object
#  6   gender          5000 non-null   object
#  7   age             5000 non-null   int64
#  8   home_address    5000 non-null   object
#  9   zip_code        5000 non-null   int64
#  10  city            5000 non-null   object
#  11  state           5000 non-null   object
#  12  country         5000 non-null   object
#  13  sales_id        5000 non-null   int64
#  14  product_id      5000 non-null   int64
#  15  price_per_unit  5000 non-null   int64
#  16  quantity        5000 non-null   int64
#  17  total_price     5000 non-null   int64
# dtypes: int64(10), object(8)
# memory usage: 742.2+ KB

# %%
df = pd.merge(df_merged_1, product, left_on='product_id', right_on='product_ID')

# %% [markdown]
# ## EDA

# %%
df.head()
# Out:
#    order_id  customer_id  payment order_date delivery_date     customer_name  \
# 0         1           64    30811  2021-8-30    2021-09-24  Annabella Devote
# 1       233          996    29939   2021-9-3    2021-09-19    Elvira Sarfati
# 2       924          786    43116   2021-4-4    2021-04-18   Lorine McLugish
# 3         1           64    30811  2021-8-30    2021-09-24  Annabella Devote
# 4        79          236    54340  2021-3-16    2021-03-25    Anders Couvert
#
#         gender  age                  home_address  zip_code  ... quantity_x  \
# 0  Genderfluid   75     4927 Alice MeadowApt. 960      7787  ...          2
# 1      Agender   59  0433 Armstrong HillSuite 974      7613  ...          3
# 2      Agender   23    145 Abigail SummitApt. 514      4731  ...          2
# 3  Genderfluid   75     4927 Alice MeadowApt. 960      7787  ...          1
# 4   Non-binary   80       64 Phillips RunApt. 722      2752  ...          2
#
#   total_price product_ID  product_type  product_name  size  colour  price  \
# 0         212        218         Shirt      Chambray     L  orange    105
# 1         318        218         Shirt      Chambray     L  orange    105
# 2         212        218         Shirt      Chambray     L  orange    105
# 3         118        481        Jacket        Puffer     S  indigo    110
# 4         236        481        Jacket        Puffer     S  indigo    110
#
#    quantity_y                                 description
# 0          44  A orange coloured, L sized, Chambray Shirt
# 1          44  A orange coloured, L sized, Chambray Shirt
# 2          44  A orange coloured, L sized, Chambray Shirt
# 3          62   A indigo coloured, S sized, Puffer Jacket
# 4          62   A indigo coloured, S sized, Puffer Jacket
#
# [5 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5000 entries, 0 to 4999
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        5000 non-null   int64
#  1   customer_id     5000 non-null   int64
#  2   payment         5000 non-null   int64
#  3   order_date      5000 non-null   object
#  4   delivery_date   5000 non-null   object
#  5   customer_name   5000 non-null   object
#  6   gender          5000 non-null   object
#  7   age             5000 non-null   int64
#  8   home_address    5000 non-null   object
#  9   zip_code        5000 non-null   int64
#  10  city            5000 non-null   object
#  11  state           5000 non-null   object
#  12  country         5000 non-null   object
#  13  sales_id        5000 non-null   int64
#  14  product_id      5000 non-null   int64
#  15  price_per_unit  5000 non-null   int64
#  16  quantity_x      5000 non-null   int64
#  17  total_price     5000 non-null   int64
#  18  product_ID      5000 non-null   int64
#  19  product_type    5000 non-null   object
#  20  product_name    5000 non-null   object
#  21  size            5000 non-null   object
#  22  colour          5000 non-null   object
#  23  price           5000 non-null   int64
#  24  quantity_y      5000 non-null   int64
#  25  description     5000 non-null   object
# dtypes: int64(13), object(13)
# memory usage: 1.0+ MB

# %%
df.isna().sum()
# Out:
# order_id          0
# customer_id       0
# payment           0
# order_date        0
# delivery_date     0
# customer_name     0
# gender            0
# age               0
# home_address      0
# zip_code          0
# city              0
# state             0
# country           0
# sales_id          0
# product_id        0
# price_per_unit    0
# quantity_x        0
# total_price       0
# product_ID        0
# product_type      0
# product_name      0
# size              0
# colour            0
# price             0
# quantity_y        0
# description       0
# dtype: int64

# %%
df.describe()
# Out:
#           order_id  customer_id       payment          age     zip_code  \
# count  5000.000000  5000.000000   5000.000000  5000.000000  5000.000000
# mean    503.038200   504.563000  33976.785000    48.760400  4912.355600
# std     285.964418   276.504896  14612.706539    17.577519  2907.367939
# min       1.000000     1.000000  10043.000000    20.000000    52.000000
# 25%     258.000000   276.000000  20627.000000    34.000000  2273.000000
# 50%     504.500000   509.000000  34259.000000    48.000000  4750.000000
# 75%     749.000000   733.000000  46608.000000    63.000000  7460.250000
# max     999.000000  1000.000000  59910.000000    80.000000  9998.000000
#
#           sales_id   product_id  price_per_unit  quantity_x  total_price  \
# count  5000.000000  5000.000000     5000.000000  5000.00000  5000.000000
# mean   2499.500000   634.053200      103.501600     1.99240   206.360000
# std    1443.520003   363.255794        9.195004     0.80751    86.357457
# min       0.000000     1.000000       90.000000     1.00000    90.000000
# 25%    1249.750000   323.000000       95.000000     1.00000   112.000000
# 50%    2499.500000   635.000000      102.000000     2.00000   204.000000
# 75%    3749.250000   951.000000      112.000000     3.00000   285.000000
# max    4999.000000  1259.000000      119.000000     3.00000   357.000000
#
#         product_ID        price   quantity_y
# count  5000.000000  5000.000000  5000.000000
# mean    634.053200   105.665400    60.083400
# std     363.255794     9.735564    11.682523
# min       1.000000    90.000000    40.000000
# 25%     323.000000    95.000000    50.000000
# 50%     635.000000   108.000000    60.000000
# 75%     951.000000   114.000000    70.000000
# max    1259.000000   119.000000    80.000000

# %%
df.describe(include='O')
# Out:
#        order_date delivery_date   customer_name  gender  \
# count        5000          5000            5000    5000
# unique        291           304             616       8
# top     2021-6-21    2021-09-12  Kristofor Roos  Female
# freq           51            49              37     712
#
#                     home_address        city            state    country  \
# count                       5000        5000             5000       5000
# unique                       616         604                8          1
# top     5567 Clarke MallApt. 756  Jordanside  South Australia  Australia
# freq                          37          37              718       5000
#
#        product_type product_name  size colour  \
# count          5000         5000  5000   5000
# unique            3           35     5      7
# top        Trousers        Denim     M   blue
# freq           1683          273  1022    762
#
#                                       description
# count                                        5000
# unique                                       1233
# top     A orange coloured, L sized, Flannel Shirt
# freq                                           13

# %%
df.corr()
# Out:
#                 order_id  customer_id   payment       age  zip_code  sales_id  \
# order_id        1.000000    -0.015749  0.008699 -0.030262 -0.072293  0.999953
# customer_id    -0.015749     1.000000 -0.015179 -0.028484  0.004816 -0.015520
# payment         0.008699    -0.015179  1.000000  0.017305  0.006845  0.008762
# age            -0.030262    -0.028484  0.017305  1.000000 -0.009591 -0.030181
# zip_code       -0.072293     0.004816  0.006845 -0.009591  1.000000 -0.072512
# sales_id        0.999953    -0.015520  0.008762 -0.030181 -0.072512  1.000000
# product_id     -0.001160    -0.014617 -0.005194 -0.005061  0.016309 -0.001371
# price_per_unit -0.001667     0.018243  0.010412  0.012690 -0.016110 -0.001624
# quantity_x      0.012749     0.014590  0.011697  0.022322  0.017419  0.012686
# total_price     0.011283     0.018069  0.013233  0.023692  0.010970  0.011228
# product_ID     -0.001160    -0.014617 -0.005194 -0.005061  0.016309 -0.001371
# price          -0.011502     0.009054 -0.001686 -0.005538  0.001066 -0.011316
# quantity_y      0.000643    -0.009934  0.018504  0.004455 -0.023266  0.000679
#
#                 product_id  price_per_unit  quantity_x  total_price  \
# order_id         -0.001160       -0.001667    0.012749     0.011283
# customer_id      -0.014617        0.018243    0.014590     0.018069
# payment          -0.005194        0.010412    0.011697     0.013233
# age              -0.005061        0.012690    0.022322     0.023692
# zip_code          0.016309       -0.016110    0.017419     0.010970
# sales_id         -0.001371       -0.001624    0.012686     0.011228
# product_id        1.000000        0.022051    0.009468     0.013958
# price_per_unit    0.022051        1.000000    0.019318     0.232178
# quantity_x        0.009468        0.019318    1.000000     0.973141
# total_price       0.013958        0.232178    0.973141     1.000000
# product_ID        1.000000        0.022051    0.009468     0.013958
# price            -0.355570       -0.121545   -0.022359    -0.046465
# quantity_y       -0.020543       -0.041999   -0.019187    -0.031757
#
#                 product_ID     price  quantity_y
# order_id         -0.001160 -0.011502    0.000643
# customer_id      -0.014617  0.009054   -0.009934
# payment          -0.005194 -0.001686    0.018504
# age              -0.005061 -0.005538    0.004455
# zip_code          0.016309  0.001066   -0.023266
# sales_id         -0.001371 -0.011316    0.000679
# product_id        1.000000 -0.355570   -0.020543
# price_per_unit    0.022051 -0.121545   -0.041999
# quantity_x        0.009468 -0.022359   -0.019187
# total_price       0.013958 -0.046465   -0.031757
# product_ID        1.000000 -0.355570   -0.020543
# price            -0.355570  1.000000    0.079856
# quantity_y       -0.020543  0.079856    1.000000

# %%
# what is the unique values in each categorical column
categorical = df.select_dtypes(["category", "object"]).columns.to_list()

# %%
for cat in categorical:
  print(f"{cat} : {df[cat].nunique()}")
  print(f"{cat} : {df[cat].unique()}")
# Out:
# order_date : 291
# order_date : ['2021-8-30' '2021-9-3' '2021-4-4' '2021-3-16' '2021-3-30' '2021-1-26'
#  '2021-10-3' '2021-3-15' '2021-8-19' '2021-7-7' '2021-4-3' '2021-2-5'
#  '2021-6-2' '2021-10-13' '2021-8-25' '2021-1-29' '2021-10-20' '2021-6-29'
#  '2021-5-26' '2021-3-22' '2021-7-25' '2021-5-5' '2021-2-3' '2021-7-19'
#  '2021-8-23' '2021-4-18' '2021-7-22' '2021-3-17' '2021-1-25' '2021-4-25'
#  '2021-2-4' '2021-9-25' '2021-9-16' '2021-7-3' '2021-4-11' '2021-5-18'
#  '2021-8-6' '2021-6-21' '2021-2-22' '2021-10-14' '2021-8-3' '2021-3-3'
#  '2021-1-9' '2021-2-11' '2021-3-28' '2021-10-21' '2021-8-17' '2021-2-25'
#  '2021-6-15' '2021-2-7' '2021-7-16' '2021-3-4' '2021-6-23' '2021-7-26'
#  '2021-6-10' '2021-4-8' '2021-10-8' '2021-6-18' '2021-9-30' '2021-4-7'
#  '2021-2-26' '2021-5-21' '2021-7-1' '2021-5-6' '2021-6-6' '2021-6-13'
#  '2021-2-18' '2021-6-20' '2021-9-6' '2021-10-17' '2021-4-15' '2021-9-18'
#  '2021-3-11' '2021-3-23' '2021-3-20' '2021-3-13' '2021-7-23' '2021-3-12'
#  '2021-1-12' '2021-1-31' '2021-4-6' '2021-10-22' '2021-2-27' '2021-9-13'
#  '2021-9-19' '2021-1-24' '2021-7-17' '2021-5-19' '2021-8-26' '2021-3-26'
#  '2021-4-22' '2021-3-14' '2021-5-29' '2021-6-26' '2021-1-17' '2021-4-27'
#  '2021-9-14' '2021-4-10' '2021-10-11' '2021-10-23' '2021-2-24' '2021-9-20'
#  '2021-7-31' '2021-10-19' '2021-4-29' '2021-4-13' '2021-7-27' '2021-9-27'
#  '2021-2-17' '2021-8-2' '2021-9-28' '2021-4-1' '2021-3-24' '2021-4-24'
#  '2021-8-29' '2021-9-17' '2021-6-7' '2021-8-18' '2021-9-24' '2021-3-29'
#  '2021-9-8' '2021-2-6' '2021-3-9' '2021-6-3' '2021-6-22' '2021-8-24'
#  '2021-10-4' '2021-2-19' '2021-8-22' '2021-4-2' '2021-9-9' '2021-6-12'
#  '2021-6-30' '2021-1-27' '2021-6-19' '2021-1-11' '2021-5-4' '2021-5-13'
#  '2021-8-14' '2021-9-26' '2021-7-4' '2021-1-4' '2021-4-5' '2021-4-19'
#  '2021-5-16' '2021-2-2' '2021-3-27' '2021-8-28' '2021-4-12' '2021-1-8'
#  '2021-8-20' '2021-6-11' '2021-9-11' '2021-7-29' '2021-4-26' '2021-5-25'
#  '2021-5-12' '2021-2-16' '2021-7-12' '2021-2-15' '2021-3-19' '2021-5-23'
#  '2021-3-7' '2021-4-14' '2021-5-11' '2021-10-15' '2021-7-9' '2021-5-22'
#  '2021-5-1' '2021-2-20' '2021-10-10' '2021-2-12' '2021-5-28' '2021-1-23'
#  '2021-1-1' '2021-8-10' '2021-1-15' '2021-4-17' '2021-9-22' '2021-7-2'
#  '2021-2-9' '2021-6-5' '2021-4-20' '2021-2-28' '2021-2-8' '2021-10-2'
#  '2021-2-13' '2021-1-22' '2021-2-14' '2021-7-6' '2021-4-16' '2021-6-27'
#  '2021-9-5' '2021-6-16' '2021-8-8' '2021-7-11' '2021-9-10' '2021-1-5'
#  '2021-8-5' '2021-5-30' '2021-1-10' '2021-8-16' '2021-1-2' '2021-9-23'
#  '2021-5-9' '2021-6-25' '2021-3-25' '2021-8-1' '2021-10-24' '2021-7-13'
#  '2021-3-21' '2021-6-17' '2021-3-10' '2021-9-29' '2021-1-6' '2021-1-13'
#  '2021-7-15' '2021-7-28' '2021-10-12' '2021-3-6' '2021-4-28' '2021-7-24'
#  '2021-7-21' '2021-9-2' '2021-7-5' '2021-3-8' '2021-3-5' '2021-4-30'
#  '2021-10-18' '2021-9-7' '2021-8-12' '2021-10-6' '2021-5-17' '2021-10-7'
#  '2021-2-23' '2021-8-4' '2021-1-18' '2021-8-15' '2021-8-31' '2021-6-1'
#  '2021-6-14' '2021-7-18' '2021-4-21' '2021-5-31' '2021-9-12' '2021-4-9'
#  '2021-9-4' '2021-3-31' '2021-7-30' '2021-1-30' '2021-5-24' '2021-8-11'
#  '2021-10-9' '2021-5-15' '2021-9-1' '2021-4-23' '2021-1-14' '2021-7-14'
#  '2021-5-10' '2021-7-20' '2021-1-16' '2021-1-21' '2021-1-19' '2021-2-21'
#  '2021-1-3' '2021-1-20' '2021-5-3' '2021-3-18' '2021-8-21' '2021-5-2'
#  '2021-9-15' '2021-5-8' '2021-8-7' '2021-7-10' '2021-1-7' '2021-7-8'
#  '2021-3-2' '2021-6-9' '2021-8-9' '2021-6-4' '2021-5-7' '2021-2-10'
#  '2021-8-13' '2021-6-28' '2021-10-16' '2021-5-27' '2021-10-5' '2021-6-24'
#  '2021-2-1' '2021-5-20' '2021-10-1']
# delivery_date : 304
# delivery_date : ['2021-09-24' '2021-09-19' '2021-04-18' '2021-03-25' '2021-02-16'
#  '2021-10-16' '2021-03-30' '2021-09-04' '2021-07-26' '2021-04-19'
#  '2021-02-10' '2021-06-11' '2021-11-09' '2021-09-13' '2021-02-05'
#  '2021-11-10' '2021-07-25' '2021-06-22' '2021-04-04' '2021-08-06'
#  '2021-05-31' '2021-02-13' '2021-08-15' '2021-09-06' '2021-04-26'
#  '2021-07-28' '2021-04-01' '2021-04-14' '2021-05-05' '2021-03-01'
#  '2021-10-20' '2021-09-18' '2021-07-09' '2021-04-22' '2021-05-24'
#  '2021-08-18' '2021-07-01' '2021-03-17' '2021-11-08' '2021-08-17'
#  '2021-03-20' '2021-01-22' '2021-02-25' '2021-04-15' '2021-11-13'
#  '2021-09-12' '2021-03-10' '2021-06-27' '2021-02-09' '2021-08-07'
#  '2021-03-22' '2021-07-20' '2021-04-27' '2021-11-03' '2021-07-05'
#  '2021-10-24' '2021-04-12' '2021-02-27' '2021-05-23' '2021-04-10'
#  '2021-04-05' '2021-01-16' '2021-10-13' '2021-05-27' '2021-06-07'
#  '2021-06-18' '2021-03-07' '2021-07-16' '2021-09-08' '2021-11-07'
#  '2021-10-10' '2021-03-31' '2021-03-24' '2021-04-09' '2021-08-14'
#  '2021-03-28' '2021-04-08' '2021-01-27' '2021-04-20' '2021-11-16'
#  '2021-10-09' '2021-02-07' '2021-08-09' '2021-07-24' '2021-06-13'
#  '2021-09-17' '2021-08-01' '2021-05-19' '2021-06-30' '2021-05-08'
#  '2021-07-22' '2021-05-03' '2021-11-17' '2021-03-18' '2021-04-21'
#  '2021-08-27' '2021-11-04' '2021-05-06' '2021-10-30' '2021-05-04'
#  '2021-02-19' '2021-07-30' '2021-10-18' '2021-09-25' '2021-03-03'
#  '2021-02-12' '2021-02-17' '2021-04-11' '2021-04-07' '2021-09-15'
#  '2021-10-06' '2021-04-03' '2021-08-30' '2021-10-14' '2021-09-28'
#  '2021-02-28' '2021-04-13' '2021-07-15' '2021-06-15' '2021-08-26'
#  '2021-07-14' '2021-06-09' '2021-10-26' '2021-08-23' '2021-10-05'
#  '2021-06-21' '2021-07-23' '2021-02-01' '2021-07-08' '2021-07-12'
#  '2021-11-12' '2021-09-27' '2021-02-03' '2021-04-17' '2021-03-23'
#  '2021-05-22' '2021-07-02' '2021-06-17' '2021-05-14' '2021-08-24'
#  '2021-07-17' '2021-05-17' '2021-04-06' '2021-01-23' '2021-04-24'
#  '2021-06-06' '2021-05-01' '2021-09-01' '2021-06-14' '2021-02-06'
#  '2021-09-20' '2021-08-02' '2021-05-20' '2021-05-28' '2021-05-18'
#  '2021-08-22' '2021-04-29' '2021-03-13' '2021-03-14' '2021-05-30'
#  '2021-07-11' '2021-02-20' '2021-06-01' '2021-07-10' '2021-03-16'
#  '2021-06-25' '2021-10-11' '2021-09-14' '2021-05-11' '2021-03-12'
#  '2021-07-07' '2021-10-15' '2021-02-08' '2021-10-17' '2021-02-18'
#  '2021-01-03' '2021-05-25' '2021-07-06' '2021-01-24' '2021-01-31'
#  '2021-08-16' '2021-10-25' '2021-09-16' '2021-09-03' '2021-02-11'
#  '2021-06-23' '2021-10-23' '2021-05-09' '2021-04-16' '2021-04-23'
#  '2021-01-29' '2021-03-02' '2021-07-13' '2021-10-12' '2021-03-08'
#  '2021-08-31' '2021-08-29' '2021-04-28' '2021-04-02' '2021-06-24'
#  '2021-09-02' '2021-10-02' '2021-01-08' '2021-08-13' '2021-01-25'
#  '2021-06-28' '2021-09-10' '2021-06-05' '2021-08-08' '2021-08-20'
#  '2021-09-11' '2021-05-16' '2021-07-21' '2021-10-31' '2021-07-18'
#  '2021-01-19' '2021-06-26' '2021-01-20' '2021-07-19' '2021-01-05'
#  '2021-09-09' '2021-06-03' '2021-05-21' '2021-10-08' '2021-01-17'
#  '2021-02-02' '2021-09-26' '2021-10-07' '2021-07-04' '2021-10-19'
#  '2021-03-04' '2021-04-30' '2021-08-25' '2021-08-10' '2021-07-27'
#  '2021-01-15' '2021-03-09' '2021-05-13' '2021-02-22' '2021-10-01'
#  '2021-03-27' '2021-09-07' '2021-07-31' '2021-09-22' '2021-06-20'
#  '2021-01-06' '2021-03-29' '2021-03-19' '2021-05-12' '2021-10-04'
#  '2021-01-21' '2021-11-20' '2021-11-02' '2021-08-03' '2021-05-29'
#  '2021-06-16' '2021-07-29' '2021-05-15' '2021-08-05' '2021-08-04'
#  '2021-02-15' '2021-02-14' '2021-06-04' '2021-10-03' '2021-02-26'
#  '2021-03-15' '2021-05-26' '2021-10-28' '2021-08-12' '2021-09-30'
#  '2021-02-04' '2021-05-10' '2021-01-09' '2021-06-02' '2021-01-07'
#  '2021-11-11' '2021-03-05' '2021-10-29' '2021-01-10' '2021-01-26'
#  '2021-09-29' '2021-03-26' '2021-08-19' '2021-05-02' '2021-03-11'
#  '2021-08-21' '2021-01-30' '2021-04-25' '2021-09-23' '2021-06-10'
#  '2021-11-01' '2021-08-11' '2021-11-14' '2021-01-12' '2021-10-22'
#  '2021-09-05' '2021-09-21' '2021-07-03' '2021-05-07' '2021-02-21'
#  '2021-06-12' '2021-11-05' '2021-06-19' '2021-01-28']
# customer_name : 616
# customer_name : ['Annabella Devote' 'Elvira Sarfati' 'Lorine McLugish' 'Anders Couvert'
#  'Datha Vicary' 'Michell Lappine' 'Ninnetta Lammin' 'Blayne Sabatier'
#  'Crin Johnikin' 'Whitney Scarman' 'Jethro Pollak' 'Binnie Gonzales'
#  'Sheff Ruoss' 'Mart Naismith' 'Patin Circuit' 'Darren Karpenko'
#  'Lindy Saltrese' 'Monica Teodorski' 'Alameda Fincke' 'Aida Warsap'
#  'Kakalina Ragge' 'Vittorio Rosenstengel' 'Lori Briars' 'Andi Kettleson'
#  'Deedee Pashe' 'Otto Matyasik' 'Dunc Swynley' 'Judith Plimmer'
#  'Alexis Maps' 'Elizabet Pippin' 'Ronni Gruszczak' 'Osgood Percifer'
#  'Theodosia Postins' 'Barclay Kinsella' 'Camile Haveline' 'Jolee Stailey'
#  'Chastity Daniaud' 'Emylee Buscher' 'Hillier Seward' 'Claudio Archibould'
#  'Denice Ledrane' 'Gates Torrance' 'Gusty Smallacombe' 'Jehanna Water'
#  'Hildegarde Bamlett' 'Selestina Dauber' 'Elbertina Gaish'
#  'Tobin Jeffryes' 'Dulcia Gawthorpe' 'Kip Cantwell' 'Hurleigh Sieb'
#  'Hayyim Trewhella' 'Caroljean Elstob' 'Dannie Fidler' 'Katalin Tellesson'
#  'Scot Billany' 'Ellynn Korba' 'Antonia Yeardsley' 'Gayleen Brookes'
#  'Perry McAless' 'Gigi Kalaher' 'Nathanil Runchman' 'Winslow Ewbanck'
#  'Alia Rapinett' 'Andrew Renn' 'Hillary Guiness' 'Merrill Care'
#  'Gertrude Harriott' 'Isidore Bleasdille' 'Nara Legerwood' 'Gunner Murdie'
#  'Robinetta Deners' 'Sonny Tremollet' 'Marthena Matterson'
#  'Beatrisa Winterscale' 'Bette-ann Harteley' 'Miner Craddock'
#  'Emanuele Deesly' 'Artemas Vasilischev' 'Olimpia Tankus' 'Brade Caught'
#  'Thorsten Sowrey' 'Katinka Currier' 'Killie Wigzell' 'Sauncho Boosey'
#  'Arlie Bowman' 'Lorilyn Vittet' 'Nicholle Coom' 'Bartel Clemendet'
#  'Rebecka Fabler' 'Persis Spiteri' 'Horatius Genever' 'Alphonse Galego'
#  'Errol Berkley' 'Michele Osmant' 'Ikey Spohr' 'Candis Roswarne'
#  'Abey Bampforth' 'Gerri McCarle' 'Rachelle Jelf' 'Ernaline Luce'
#  'Meredith Canniffe' 'Faber Purcell' 'Dame Popov' 'Hoebart Edger'
#  'Pietro Duling' 'Jania Sailes' 'Tomaso Mullin' 'Tressa Cunnane'
#  'Herschel Verdey' 'Silas Stephens' 'Harrietta Burchatt'
#  'Ellerey Kaesmakers' 'Hetti Fibbens' 'Melissa Partkya' 'Jakob Munks'
#  'Jerald MacMeeking' 'Gorden Seago' 'Winn Siemandl' 'Bank Sargeaunt'
#  'Pieter Bruton' 'Brodie Hedin' 'Constantino Langworthy' 'Leandra Derks'
#  'Silvie Bortol' 'Kayley Brosoli' 'Vinnie Feaver' 'Sharleen Langworthy'
#  'Robena Gilbert' 'Meryl Neeson' 'Carlynn McCabe' 'Fabian Gostage'
#  'Bay Kraut' 'Saul Franklyn' 'Rachel Colebrook' 'Alina Strotton'
#  'Fanchette Polak' 'Berry Rosiello' 'Lucas Cromly' 'Farah Schukert'
#  'Atlante Dissman' 'Isahella Enrique' 'Darby Jeffries' 'John Panchen'
#  'Barclay Beswick' 'Sandy Yushachkov' 'Glyn Tieman' 'Clayson Mealing'
#  'Neilla Halladey' 'Gert Brackstone' 'Sharyl Royl' 'Eba Bauser'
#  'Waylen Swallwell' 'Mallissa Lawdham' 'Vicki Stockwell' 'Ettie Gonnely'
#  'Katusha Ceney' 'Ellyn Collacombe' 'Brooks Sayers' 'Riordan Goreway'
#  'Griffy Wenger' 'Thorny Nornable' 'Jaquelyn Dow' 'Merl Gayforth'
#  'Hilda Peter' 'Tommie Benoy' 'Daren Airs' 'Lavina Dartnell'
#  'Seana Hearons' 'Otha Skein' 'Timmie Kelshaw' 'Kristofor Roos'
#  'Tobye De Caville' 'Marget Kells' 'Tann Scothron' 'Marilyn Rontree'
#  'Beverly Burbridge' 'Rey Grasner' 'Faunie Cooney' 'Denny Parlour'
#  'Herbert Rock' 'Aurie Margett' 'Constance Piddington' 'Bucky Cragell'
#  'Jeff Curness' 'Cherlyn Asmus' 'Collie Jakel' 'Brendis Blackboro'
#  'Jacquelin Santostefano.' 'Zebulen Zannotti' 'Matilde Yanuk'
#  'Calhoun Raphael' 'Stephen MacAleese' 'Nady Buston' 'Wanids Cudby'
#  'Camellia Heatherington' 'Brod Phifer' 'Damiano Leyborne'
#  'Atlante McGrotty' 'Chandra Carine' 'Chandal Fransinelli'
#  'Pen Andrzejczak' 'Stanleigh Hazelton' 'Lucias Forsythe'
#  'Kristel Klaaassen' 'Gwenette Kahen' 'Mallory Castellani' 'Meade Yglesia'
#  'Jamesy Rennles' 'Kendall Jakubski' 'Ira Dafforne' 'Hadley Baddam'
#  'Paul McGavigan' 'Alair Grimwad' 'Else Bicheno' 'Kerry Luto'
#  'Kaitlin Jeanes' 'Guthry Ure' 'Duncan Walliker' 'Elga Corgenvin'
#  'Ellene Dedam' 'Nicole Cheel' 'Perceval Umbers' 'Raul Pockey'
#  'Nelli Engall' 'Theodor Skipton' 'Avivah Roddick' 'Marni Figiovanni'
#  'Carmita Grundey' 'Anny Midden' 'Brenden Roast' 'Trista Aspray'
#  'Ashlie Godwyn' 'Diann Grieger' 'Kalil Thal' 'Isaak Ferrarone'
#  'Melodee Spencley' 'Hunfredo Peyto' "Valerie D'Errico" 'Jillian Sauven'
#  'Elaina Agate' 'Margalo Cousen' 'Aindrea Franzetti' 'Sherwynd Batsford'
#  'Geraldine Naulty' 'Lynda Seydlitz' 'Ulla Crombie' 'Wilhelm Blaber'
#  'Mady Greenleaf' 'Emmalee Camin' "Martin O'Mailey" 'Gallard Mangan'
#  'Yardley Dreamer' 'Gertrudis Pergens' 'Hilliard Papes' 'Clem Margetts'
#  'Ann-marie Sinden' 'Kellie Curbishley' 'Henrietta Briatt'
#  'Peri Pilsworth' 'Beverlie Bansal' 'Lauryn Deport' 'Christi Reston'
#  'Tucky Kitchaside' 'Hew Cardinal' 'Leeann Gowdie' 'Augusto Ackrill'
#  'Rutger Hugonnet' 'Erroll Michelle' 'Haslett Edwins' 'Daisy Camillo'
#  'Vladimir Jandourek' 'Aldin Moline' 'Kyle Lowbridge' 'Taffy Quimby'
#  'Jillana Blankau' 'Wenona Stuck' 'Eada Viccary' 'Margret Yeabsley'
#  'Trenton Lydiard' 'Konstantin Kuhlmey' 'Channa Powley' 'Didi Garton'
#  'Joelynn Remington' 'Glenn Keri' 'Marnie Dennington' 'Alexei Hurburt'
#  'Amalia Eallis' 'Cary Boaler' 'Bird McGarvie' 'Thomasine Baudet'
#  'Darrelle Padson' 'Dean McLarty' 'Marlee Edser' 'Hadlee Douthwaite'
#  'North Diamond' 'Ailina Kynan' 'Minta Loble' 'Tore Caras' 'Silas Chaman'
#  'Felic Marrian' 'Lenna Beau' 'Orton Heigl' 'Albina Disdel' 'Orran Skip'
#  'Maegan Ashton' 'Waylin Gasson' 'Lizette Lindro' 'Eloise Ondrusek'
#  'Luelle Fernanando' 'Adamo Saddington' 'Murdock Bulfit' 'Hort Ridding'
#  'Shoshana Redsell' 'Pate De Ambrosis' "Paxon O'Shiel" 'Merrielle Piken'
#  'Chancey Iacovozzo' 'Zaria Garken' 'Sigmund Bothen' 'Beckie Nasey'
#  'Violet Alwen' 'Zeb Shipton' 'Slade Villaret' 'Chan Duchesne'
#  'Malory Emmison' 'Lisle Worthing' 'Wald Kaine' 'Valentine Marley'
#  'Sharl Izzett' 'Mandel Fairbanks' 'Valery Pache' 'Wash Kyneton'
#  'Tommy Ebunoluwa' 'Shelbi Impson' 'Lesli Pitfield' 'Grady Wipper'
#  'Geri Renton' 'Ninon Corteney' 'Mira Heinonen' 'Ianthe Magowan'
#  'Cosmo Leys' 'Giles Kyne' 'Grissel Harteley' 'Angie O Mullen'
#  'Felice Dumbleton' 'Joannes Pandie' 'Benji Vineall' 'Garvy Davioud'
#  'Lyn Bouts' 'Sigismundo Basek' 'Tracie Okey' 'Etan Peirazzi'
#  'Esteban Hensmans' 'Calypso Ellaway' 'Francklyn Willeman' 'Normy Anlay'
#  'Trudey Betteridge' "Hildagarde Dell 'Orto" 'Gina Pollen' 'Toddie Snow'
#  'Joby Law' 'Dani Hawtin' 'Lindsey McCuthais' 'Corri Womack' 'Sadye Pes'
#  'Ashley Gant' 'Rowena Soall' 'Gabbie Aldwinckle' 'Gabriella Nutman'
#  'Adena Venn' 'Darby Aistrop' 'Roley Cassedy' 'Sheela Dovey'
#  'Ranna Paolillo' 'Bone Perche' 'Hana Stitch' 'Reed Churchlow'
#  'Willa Gaisford' 'Marena Lockhart' 'Valentino Branney' 'Sol Adhams'
#  'Vite Durrant' 'Kerianne Parris' 'Wren Helgass' 'Fedora Dmych'
#  'Frayda Simonini' 'Morie Woodfield' 'Crawford Bolden' 'Avril Rossiter'
#  'Joy Mirrlees' 'Henryetta Sheffield' 'Meris Twitty' 'Debee Lording'
#  'Shaylyn Musla' 'Uriel Cottingham' 'Leonore Yakunikov' 'Gareth Bindon'
#  'Gibbie Beardall' 'Zak Titterton' 'Jojo Toffanini' 'Ansel Chittem'
#  'Noel Siviour' 'Nixie Fraczak' 'Dena Banbrick' 'De Lourens'
#  'Julian Sponer' 'Jarrett Brumby' 'Judy Mesias' 'Cassaundra Sliman'
#  'Teddy Gell' 'Ephrem Hambers' 'Eustacia Andreassen' 'Stanley Kolakowski'
#  'Wadsworth Olivier' 'Timothy Compston' 'Niels Loadsman' 'Ailene McKeller'
#  'Shelden Tinline' 'Conny Chowne' 'Worthington Knapton' 'Cad Dominichetti'
#  'Amaleta Beange' 'Meryl Kender' 'Shanna Pietrzyk' 'Delia Mably'
#  'Moore Oolahan' 'Bourke Pembery' 'Codie Everly' 'Alis MacCulloch'
#  'Iago Jedrzaszkiewicz' 'Dulsea Collet' 'Hobie Anfusso' 'Alexis Cheake'
#  'Rafferty Fronek' 'Kendre Etherton' 'Lanny Wardale' 'Romy Cuberley'
#  'Jermaine Goranov' 'Augustin Brandenberg' 'Erik Osgar' 'Nessy Kildea'
#  'Averyl Atthow' 'Tymothy Linsay' 'Lorenzo Dutch' 'Ashely Inmett'
#  'Isis Doel' 'Jan Isenor' 'Drake Ivanilov' 'Lacee Denyukin'
#  'Matthiew Hinckes' 'Vida Matchitt' 'Hi Simenel' 'Monty Gowen'
#  'Morgana Weymouth' 'Iain Fellnee' 'Alon Abramsky' 'Jayme Turvie'
#  'Lin Norville' 'Lars Stading' 'Annice Kelcey' 'Dani Pinches'
#  'Orella Singyard' 'Hal Saker' 'Dare Andrich' 'Edithe Yitshak'
#  'Ninetta Phizakarley' 'Delcine Pickthorn' 'Thoma Seaking' 'Benny Songist'
#  'Sutherlan Stepto' 'Curtis McCarroll' 'Krystle Boyce' 'Hughie Trelease'
#  'Myrle Kelby' 'Archibaldo Taffurelli' 'Terri Lunny' 'Udale Ripping'
#  'Cacilie Forrestill' 'Araldo Washtell' 'Joella Tiddeman' 'Persis Linch'
#  'Frederique Hopkins' 'Angelle Huby' 'Eryn Harcus' 'Tammie Gavrielli'
#  'Cornie Virr' 'Zorina Rabl' 'Nanny Franey' 'Cristina Jowling'
#  'Worthy Pardoe' 'Dag Schiefersten' 'Prissie Dumelow' 'Pierre Rockwill'
#  'Carlen Kelway' 'Randell Shorte' 'Mellisent Druhan' 'Mariellen Medendorp'
#  'Mycah Rodie' 'Rowena Doe' 'Lilyan Pirt' 'Brian Finnes'
#  'Lorelle Lancastle' 'Nerita Peotz' "Berri O' Clovan" 'Mirabelle Vaney'
#  'Carla Walework' 'Corinna Maystone' 'Alicea Momford' 'Marabel Swinfon'
#  'Beverlie Blance' 'Reba Crauford' 'Kinny Roget' 'Elianore Syphas'
#  'Meghan Simic' 'Cherie Fairhead' 'Regan Gronaller' 'Marinna Heal'
#  'Zebulon Rousel' 'Jedidiah Sydall' 'Devin Lindmark' 'Alayne Ipplett'
#  'Raul Crilly' 'Chadwick Cruddas' 'Angil Crunden' 'Tiphany Peacop'
#  'Cy Sabbins' 'Lisetta Griffin' 'Jena Kelling' 'Millicent Stedson'
#  'Willey Tolley' 'Phillipe Gatecliffe' 'Milton Otson' 'Roobbie Persich'
#  'Nicky Giuron' 'Con Pressdee' 'Avivah Chipchase' 'Dolph Arrow'
#  'Engracia Abilowitz' 'Rorie Hof' 'Puff Newbury' 'Vincent Kiledal'
#  'Daria Embleton' 'Devonne Martinetto' 'Marvin Van Hault' 'Angela Kester'
#  'Loni Tort' 'Dianemarie Neicho' 'Eve Stutard' 'Tally Rubel'
#  'Muire Ashtonhurst' 'Vin Rubenovic' 'Courtnay Cornewell'
#  'Shena Solomonides' 'Lawry Mannooch' 'Lionel Mansel' 'Evelyn Chevolleau'
#  'Jaymee Dalrymple' 'Shermy Mulbry' 'Cecilla Pigford' 'Leroi Weal'
#  'Michaeline McIndrew' 'Law Foker' 'Lilli Bavester' 'Barbara-anne Salerg'
#  'Marci Borrett' 'Bee Mazonowicz' 'Raquela Swinnard' 'Frederich Duigenan'
#  'Justin Marden' 'Kayne Fraczkiewicz' 'Giralda Trewin' 'Susanetta Wilshin'
#  'Vanna Densham' 'Malcolm Paal' 'Whitaker Pashen' 'Marna Lammerts'
#  'Cindi McCague' 'Lin Avraam' 'Leanna Busson' 'Jeanne Pringer'
#  'Prissie Kondratovich' 'Sadella Goodsall' 'Biddy Devanney'
#  'Jammal Varcoe' 'Saxe Stormonth' 'Ringo Sollars' 'Kellyann Stening'
#  'Ondrea Apark' 'Hyacinth Pepper' 'Leann Kittow' 'Eddie Elcott'
#  'Yevette Weekes' 'Camala Llywarch' 'Bobbi Pickerill'
#  'Nathaniel McCandless' 'Ginnie Glasheen' 'Jillene Goodbanne'
#  'Bunni Poundsford' 'Etheline Bahde' 'Charles Duffitt' 'Salomo Shuttell'
#  'Edee Wildt' 'Jan Gligori' 'Cinda Alleyne' 'Dulcea Shrawley'
#  'Aldridge Tesh' 'Chaddie Fawlkes' 'Olympia Stobbs' 'Glynda Dodshon'
#  'Egon Figliovanni' 'Drusi Eagell' 'Curcio Kiffin' 'Kaitlyn Pinare'
#  'Deirdre Burle' 'Cristen Hagley']
# gender : 8
# gender : ['Genderfluid' 'Agender' 'Non-binary' 'Polygender' 'Bigender' 'Female'
#  'Genderqueer' 'Male']
# home_address : 616
# home_address : ['4927 Alice MeadowApt. 960' '0433 Armstrong HillSuite 974'
#  '145 Abigail SummitApt. 514' '64 Phillips RunApt. 722'
#  '587 Dooley AvenueSuite 138' '9726 Eliza GroveApt. 938'
#  '94 Hayden LaneSuite 912' '292 Casper IslandSuite 778'
#  '09 Kiehn View RdApt. 209' "01 D'amore ManorSuite 692"
#  '7812 Towne GroveSuite 233' '5756 Savannah DriveApt. 644'
#  '269 Cartwright ParadeSuite 150' '562 Mann MeadowApt. 977'
#  '976 Murray Station StApt. 036' '73 Amelie LoopApt. 987'
#  '15 Bruen SummitApt. 152' '100 Stokes ParkwayApt. 307'
#  '6239 Kreiger HillApt. 899' '11 Joel CircuitSuite 126'
#  '69 Sophie PlazaSuite 598' '5855 Isaac RunApt. 434'
#  '531 Schmitt BoulevardApt. 010' '3767 Mackenzie Estate DrApt. 877'
#  '96 Bartoletti StreetApt. 671' '35 Hall PlazaSuite 535'
#  '621 Eve View RdApt. 900' '271 Ava MewsApt. 686'
#  '591 Sarah PassSuite 334' '14 Clark PlazaSuite 716'
#  '535 Angelina CourtSuite 875' '7219 Charlotte SummitSuite 507'
#  '1853 Dickens LaneSuite 406' '698 Doyle RoadSuite 219'
#  '408 Logan View RdApt. 841' '046 Leah RidgeSuite 190'
#  '33 Hamish ParkwayApt. 423' '133 Doyle PassSuite 027'
#  '11 Savannah LaneSuite 334' '0487 Jordan TerraceSuite 509'
#  '049 Imogen StreetSuite 299' '26 Willow CourtApt. 822'
#  '49 Lily RidgeSuite 143' '672 Graham MewsApt. 407'
#  '47 Stanton GroveSuite 963' '275 Maddison Estate DrApt. 642'
#  '6801 Jessica JunctionApt. 868' '23 Zara KnollApt. 502'
#  '7204 Toby SummitApt. 845' '157 Rice LoopSuite 716'
#  '1737 Schroeder LoopSuite 349' '8662 Maya PlaceApt. 834'
#  '5990 John View RdApt. 812' '157 Rohan MallApt. 466'
#  '286 Chase IslandSuite 443' '4966 Lilly Estate DrApt. 570'
#  '2096 Wilson MewsApt. 714' '96 Gabriel AvenueApt. 145'
#  '18 Lachlan CourtApt. 781' '082 Donnelly BoulevardSuite 569'
#  '2069 Phoebe MallApt. 543' '831 Ava SquareApt. 776'
#  '92 Hills Station StApt. 683' '7299 Madeline MeadowApt. 450'
#  '761 Mckenzie BoulevardSuite 489' '74 Eva TerraceSuite 247'
#  '7285 Mason BoulevardSuite 754' '7377 Nicolas ParadeApt. 191'
#  '69 Michael PlazaApt. 659' '74 Anderson RoadApt. 779'
#  '7504 Phoebe RoadApt. 552' '32 Chase JunctionSuite 463'
#  '6481 Isaac LoopApt. 355' '5420 Amelia IslandSuite 286'
#  '74 Ryan CircleSuite 426' "051 O'conner Station StSuite 626"
#  '8353 Bruen ParkwayApt. 455' '83 Jordan DriveApt. 011'
#  '33 Richards JunctionApt. 478' '6434 Callum RoadApt. 396'
#  '38 Baumbach Estate DrApt. 545' '7024 Sauer DriveSuite 553'
#  '96 Caitlin HillSuite 366' '4493 Doyle WayApt. 026'
#  '9003 Gemma RidgeApt. 954' '04 Christian RidgeApt. 329'
#  '8307 Matthew GroveSuite 475' '0663 Hayley TerraceApt. 069'
#  '46 Gemma BoulevardSuite 507' '72 Annabelle PassApt. 446'
#  '844 Alana LaneApt. 225' '778 Wilkinson RidgeSuite 101'
#  '553 Alexander TrailSuite 694' '063 Huel StreetApt. 758'
#  '370 Koch SummitApt. 142' '338 Mckenzie PlaceSuite 622'
#  '5777 Mayer PassApt. 881' '3543 Jack GroveApt. 595'
#  '269 Kuhn PlazaApt. 260' '6472 Georgia CircuitApt. 986'
#  '02 Gabriella PlazaApt. 474' '120 Eli PlazaApt. 906'
#  '783 Olivia CrescentSuite 877' '46 Spencer MeadowSuite 241'
#  '27 Kiara MeadowSuite 662' '575 Olson MallApt. 344'
#  '251 Graham KnollSuite 970' '51 Gabriel KnollApt. 819'
#  '7120 Piper Station StSuite 874' '2752 Lily RoadApt. 721'
#  '344 Addison PlazaApt. 998' '8125 Durgan BoulevardSuite 068'
#  '56 Marcus SquareSuite 361' '019 Lang SquareSuite 468'
#  '95 Rice Station StSuite 985' '27 Hermann ManorSuite 124'
#  '5040 Isabel TerraceSuite 158' '905 Stephanie BoulevardApt. 217'
#  '443 Holly AvenueSuite 631' '74 King SummitSuite 021'
#  '26 Jayden IslandSuite 937' '6428 Boyle MallApt. 711'
#  '316 Violet LaneApt. 212' '19 Jordan Station StSuite 655'
#  '90 Fisher RoadSuite 844' '59 Hand ManorApt. 544'
#  '18 Jack JunctionSuite 575' '317 Sophia MewsApt. 328'
#  '6873 Berge StreetApt. 755' '7490 Lily WaySuite 419'
#  '82 Hayden DriveSuite 289' '11 Nader ParadeApt. 016'
#  '688 Campbell RoadSuite 011' '82 Kirlin StreetSuite 641'
#  '6553 Gibson AvenueSuite 245' '2501 Hackett ManorSuite 051'
#  '1936 Mccullough RidgeApt. 438' '682 Alyssa CrestApt. 916'
#  '079 Chase MallApt. 902' '58 Heaney SquareApt. 870'
#  '80 Charles CircuitSuite 023' '43 Oscar LoopSuite 946'
#  '704 Wright CourtApt. 223' '35 Barrows RunApt. 970'
#  '667 Feil RidgeSuite 935' '20 Morrison RoadSuite 781'
#  '37 White Station StApt. 524' '94 Hannah LoopSuite 177'
#  '95 Grimes ParkwaySuite 469' '89 Schmitt PlazaSuite 421'
#  '29 Caitlin CrestSuite 875' '984 Boyer KnollApt. 699'
#  '254 Layla AvenueSuite 506' '96 Bode RidgeApt. 090'
#  '3101 Thomson ManorApt. 600' '6172 Andrew AvenueApt. 194'
#  '3570 Sarah AvenueApt. 092' '786 Paige CircleApt. 922'
#  '64 Champlin ParkwayApt. 832' '256 Andrew CrestApt. 193'
#  '8649 Phillips KnollSuite 008' '4070 Nathan CircuitSuite 296'
#  '854 John GroveApt. 925' '769 Gibson TrailApt. 359'
#  "4435 O'hara TerraceSuite 232" '1130 Turner Estate DrSuite 925'
#  '378 John MallSuite 835' '0380 Bartell StreetSuite 585'
#  '93 Doherty MewsSuite 649' '368 Morrison MeadowApt. 117'
#  '424 Howell GroveApt. 432' '5567 Clarke MallApt. 756'
#  '987 Charlotte MewsApt. 591' '4399 Stephanie JunctionSuite 829'
#  '72 Hunter Station StApt. 220' '9100 Kovacek GroveSuite 577'
#  '155 Hayes AvenueApt. 699' '50 Layla RunApt. 551'
#  '36 Christian PlaceApt. 409' '2785 Morgan BoulevardApt. 849'
#  '04 Dare TerraceSuite 650' '260 Lily PassSuite 549'
#  '135 Ella RunApt. 424' '345 Elijah TrailSuite 066'
#  '86 Christiansen HillSuite 955' '003 Bruen DriveApt. 633'
#  '40 Mitchell CrestSuite 035' '17 Beatty Station StApt. 918'
#  '04 Stewart WaySuite 826' '868 Skye MeadowSuite 990'
#  '17 Jade AvenueApt. 646' '68 Darcy PassSuite 091'
#  '72 Edward ParkwaySuite 980' '0390 Stark RoadApt. 898'
#  '80 Chelsea KnollApt. 014' '5530 Ashton GroveSuite 128'
#  '05 Fahey CircleSuite 721' '6166 Durgan WayApt. 693'
#  '2352 Luca JunctionApt. 067' '1805 Harry RoadApt. 445'
#  '7048 Barrows CrescentSuite 562' '09 Baumbach LoopSuite 059'
#  '8676 William HillApt. 725' '122 Riley TrailSuite 946'
#  '09 Jesse ParadeApt. 250' '953 Durgan GroveApt. 655'
#  '115 Wilkinson CrestSuite 858' '624 Bode TrailSuite 795'
#  '835 Mayer ParkwaySuite 374' '331 Leah Station StSuite 445'
#  "14 O'neill View RdApt. 908" '360 Heller DriveApt. 052'
#  '7367 Wright JunctionApt. 773' '682 Rose CircleApt. 514'
#  '958 Connor MewsSuite 524' '0872 Gemma ParadeApt. 070'
#  '709 Abigail ParadeApt. 339' '400 Beau PlaceSuite 439'
#  '861 Thomas LoopApt. 385' '0462 Fisher TrackSuite 627'
#  '86 Crooks CrescentSuite 269' '550 Alexis BoulevardSuite 124'
#  '5200 Tromp Estate DrSuite 885' '178 Smitham GroveSuite 638'
#  '58 Jett RoadApt. 448' '48 Mikayla IslandApt. 883'
#  '606 Lucy ParadeSuite 217' '8580 Moss RoadApt. 681'
#  '985 Ethan AvenueSuite 122' '810 Jasper CircleSuite 777'
#  '614 Cooper RunSuite 917' '9347 Morrison RoadSuite 865'
#  '2872 Samantha ParkwaySuite 016' '803 Lara DriveApt. 182'
#  '78 Cassin SquareApt. 019' '074 Hackett ParadeApt. 191'
#  '033 Mitchell IslandApt. 732' '68 Doyle View RdSuite 917'
#  '607 Parisian AvenueSuite 494' '99 Sophia TrailApt. 477'
#  '596 Martin BoulevardApt. 367' '97 Isaac SummitSuite 935'
#  '13 Ivy TerraceSuite 494' '627 Weber PassApt. 498'
#  '491 Fisher IslandSuite 745' '246 Waters CrescentSuite 947'
#  '5302 Ava TerraceApt. 295' '093 Jessica AvenueSuite 154'
#  '8756 Tremblay RunSuite 034' '7571 Nolan CrestSuite 040'
#  '639 Griffiths ParkwayApt. 162' '24 Jake MeadowApt. 433'
#  '8083 Paterson RoadApt. 211' '653 Jones AvenueApt. 945'
#  '2376 Adams SquareSuite 443' '6744 Joshua RoadApt. 554'
#  '017 Doherty DriveSuite 350' '347 Gleason View RdApt. 168'
#  '708 Cole PlazaSuite 178' '409 Alyssa CourtApt. 204'
#  '0358 Ashley WayApt. 506' '47 Green ParkwayApt. 868'
#  '70 Phoenix DriveApt. 109' '381 Matthew Estate DrSuite 656'
#  '29 David JunctionApt. 733' '8183 Alexis JunctionApt. 634'
#  '89 Charles GroveApt. 955' '13 Hammes CircuitApt. 503'
#  '694 Isabella WaySuite 054' '140 Jessica BoulevardApt. 214'
#  '5310 Lewis TrailApt. 715' '950 Smith DriveApt. 385'
#  '7210 Farrell HillApt. 735' '39 Liam ParadeApt. 343'
#  '1033 Botsford Estate DrSuite 236' '82 Beahan BoulevardSuite 281'
#  '71 Jade CrescentApt. 142' '72 George CourtApt. 482'
#  '543 Nader CrestSuite 019' '30 Williamson SummitApt. 594'
#  '3463 Joshua SummitApt. 971' '87 Oliver TerraceApt. 608'
#  '13 Ivy BoulevardSuite 234' '94 Archie CourtSuite 659'
#  '4838 Jacobi HillApt. 825' '644 Sophie LoopSuite 596'
#  '0544 Zoe CourtSuite 153' '2004 Sebastian CrescentApt. 895'
#  '623 Abigail BoulevardSuite 973' '889 Hermann Station StApt. 026'
#  '313 Grace LoopApt. 523' '22 Aaron LoopApt. 324'
#  '6303 Nate BoulevardSuite 368' '4207 Hudson CrescentSuite 167'
#  '19 Lola View RdApt. 937' '85 Mitchell StreetSuite 398'
#  '459 Sarah TerraceApt. 121' '195 Wilson HillApt. 597'
#  '2912 Adams JunctionSuite 740' '410 Ryan CrescentApt. 461'
#  '5215 Mitchell TrackSuite 778' '76 Thomas ParkwaySuite 490'
#  '01 Piper ManorApt. 376' '639 Emard PlaceSuite 924'
#  '95 Skye PassApt. 600' '06 Ebert CrestSuite 385'
#  '69 Sebastian Estate DrSuite 727' '380 Hamish LaneApt. 098'
#  '07 Lily LoopSuite 494' '855 Beahan IslandSuite 560'
#  '3168 Bartoletti CrescentSuite 878' '5233 Lara AvenueSuite 291'
#  '64 Andrew StreetSuite 948' '65 Schroeder WayApt. 552'
#  '65 Eli AvenueApt. 473' '0398 Jayden TrailApt. 929'
#  '9182 Hermann MallApt. 890' '501 Nader RidgeApt. 355'
#  '53 Jake CourtSuite 337' '1621 Marcus MeadowApt. 603'
#  '42 Max View RdSuite 078' '339 Hermann ParadeSuite 489'
#  '970 Khan RidgeApt. 056' '66 Mason CrescentSuite 942'
#  '13 Bailey ManorApt. 848' '118 Levi CrestApt. 495'
#  '8360 Poppy SummitSuite 841' '5135 Leah RoadSuite 306'
#  '31 Aaron WayApt. 752' '9871 Bailey SquareApt. 697'
#  '1671 Lauren KnollSuite 945' '3203 Jackson TerraceSuite 580'
#  '539 Towne CrescentSuite 935' '56 Wolf TerraceSuite 373'
#  '20 Xavier RidgeApt. 805' '617 Scarlett BoulevardApt. 858'
#  '900 Jade AvenueApt. 206' '268 Bayer SquareApt. 041'
#  '09 Robinson SquareApt. 647' '2719 Dietrich KnollApt. 175'
#  '35 Baumbach HillApt. 244' '012 Eli RidgeSuite 727'
#  '91 Angelina RidgeApt. 435' '8778 Liam TerraceSuite 662'
#  '8397 Davis CrescentApt. 905' '3744 Max PlaceApt. 109'
#  '5778 Chloe CourtApt. 365' '468 Shields CircleApt. 480'
#  '461 Nader LaneApt. 460' '16 Maddison MewsSuite 093'
#  '4355 Caitlin CourtApt. 697' '056 Khan RidgeSuite 131'
#  '8162 James TrackApt. 724' '098 Clarke ParkwayApt. 312'
#  '174 Thomson StreetSuite 883' '22 Ellie View RdApt. 141'
#  '10 Imogen PassSuite 135' '2115 Henry GroveSuite 788'
#  '59 Henry PlaceSuite 781' '22 Welch DriveSuite 750'
#  '19 Young IslandSuite 543' '868 Eliza CrescentSuite 085'
#  '41 Brown Estate DrSuite 039' '1029 Eva JunctionApt. 767'
#  '051 White WayApt. 392' '0986 Mccullough MewsSuite 467'
#  '458 Imogen Station StSuite 799' '0479 Oliver View RdApt. 112'
#  '424 Mason PlaceApt. 181' '06 Leah RoadSuite 691'
#  '048 Kayla RoadSuite 099' '78 Ryan TrackSuite 283'
#  '59 Abbott CircuitApt. 084' '201 Anthony TerraceSuite 543'
#  '1804 Ella HillSuite 318' '638 Thomas ManorApt. 038'
#  '647 Violet Estate DrSuite 364' '4592 Isabella BoulevardApt. 793'
#  '373 Little JunctionApt. 299' '012 Cooper MallApt. 259'
#  '8753 Jasper PlaceApt. 474' '010 Cartwright TrackApt. 920'
#  '31 King LoopSuite 647' '59 Bergstrom GroveSuite 260'
#  '2634 Ward CrescentSuite 361' '66 Kayla MewsSuite 951'
#  '774 Christiansen StreetSuite 261' '8007 Joel SquareApt. 874'
#  '63 Charlie LaneSuite 463' '254 Ali RidgeApt. 350'
#  '04 Spencer MallApt. 910' '164 Bruen MallSuite 043'
#  '708 Daniel MeadowSuite 246' '090 Christopher PlaceApt. 513'
#  '814 Jayden MewsSuite 958' '7427 Stark CrescentSuite 975'
#  '59 Gibson MeadowApt. 565' '8557 Bogan AvenueSuite 811'
#  '401 Langworth CircuitSuite 015' '017 Maddison KnollSuite 875'
#  '3285 Kai MewsApt. 727' '22 Eve CrescentApt. 357'
#  '8557 Samantha GroveApt. 570' '164 David View RdApt. 020'
#  '80 Adam HillSuite 633' '334 Olivia MeadowSuite 855'
#  '745 Jack CourtApt. 737' '59 Wood DriveSuite 806'
#  '933 Jake CrestSuite 613' '3679 Kiehn ParkwaySuite 444'
#  '29 Bruen TrailSuite 288' '6502 Abbey ParadeSuite 954'
#  '3414 Mia MallApt. 446' '7295 Champlin CrestApt. 519'
#  '4309 Nguyen KnollApt. 851' '499 Darcy CrestApt. 192'
#  '0204 Andrew JunctionApt. 904' '9444 Casper RidgeApt. 537'
#  '93 Amy GroveApt. 822' '09 Christopher View RdApt. 739'
#  '88 Walsh WaySuite 074' '556 Jacobson PlaceApt. 974'
#  '26 Martin RoadSuite 393' '0052 Benjamin MewsApt. 635'
#  '30 Watson WayApt. 179' '18 Eve LaneApt. 011' '13 Stokes SummitApt. 125'
#  '599 Campbell CrestApt. 125' '66 Isla CrescentApt. 573'
#  '8142 Jackson ParkwaySuite 475' '00 Lockman TrackSuite 564'
#  '23 Smith StreetSuite 253' '5157 Feil RoadApt. 633'
#  '60 Nolan LaneSuite 078' '068 Logan CourtSuite 319'
#  '3627 Chloe Estate DrSuite 963' '4870 Jackson SummitApt. 538'
#  '06 Toby KnollApt. 679' '9937 Oliver CircleApt. 655'
#  '20 Skye RunApt. 868' '6022 Jonathan TrackSuite 607'
#  '9398 Schneider RidgeSuite 818' '24 Alexis BoulevardSuite 321'
#  '38 Charli SquareSuite 502' '81 Heidi MeadowSuite 615'
#  '625 Anthony MewsApt. 730' '540 Schmitt ParkwaySuite 102'
#  '6863 Tremblay KnollSuite 290' '107 Wilkinson ParkwaySuite 249'
#  '040 Patrick Estate DrApt. 254' '1290 Koch GroveApt. 799'
#  '69 Aiden ParkwaySuite 721' "78 O'hara CircuitApt. 096"
#  '651 Garden CourtApt. 769' '843 Goodwin MewsApt. 699'
#  '476 Corwin ParkwayApt. 441' '0260 Garden StreetSuite 683'
#  '6578 Kayla AvenueSuite 812' '84 Stewart StreetSuite 032'
#  '6724 Little SummitApt. 635' '66 Jacob PassSuite 159'
#  '83 Reynolds ParadeSuite 974' '327 Abby CircleApt. 055'
#  '64 Aiden View RdSuite 085' '609 Rohan TerraceSuite 767'
#  '74 Justin SummitSuite 427' '716 Max IslandSuite 824'
#  '967 Skye DriveApt. 746' '985 Nguyen TerraceApt. 362'
#  '165 Hermiston LoopSuite 403' '9585 Bogan PlazaSuite 155'
#  '4036 Thompson StreetApt. 565' '16 Thomson PlazaSuite 403'
#  '5014 Gemma ParadeSuite 066' '85 Charles MallSuite 424'
#  '457 Evans View RdApt. 385' '4627 Paige KnollApt. 635'
#  "313 O'hara Estate DrSuite 414" '0189 Anna KnollSuite 703'
#  '9173 Maya SummitApt. 856' '887 Goldner PlazaSuite 053'
#  '102 Mitchell IslandSuite 599' '6601 Grimes CircuitApt. 442'
#  '9838 Madison GroveApt. 181' '2813 Hall ParkwaySuite 251'
#  '06 Eve RunApt. 689' '41 Feeney ParkwaySuite 074'
#  '7615 Hyatt TrailSuite 179' '9268 Swift SummitSuite 218'
#  '8164 Stanton IslandApt. 438' '71 Joseph TrailApt. 169'
#  '199 Amber MallSuite 954' '98 Ellie CircleSuite 311'
#  '09 Doyle MallApt. 066' '74 Aaron HillSuite 794'
#  '69 Morissette AvenueSuite 269' '970 Braun MewsApt. 629'
#  '16 Boyer WaySuite 018' '3087 Victoria DriveApt. 454'
#  '9388 Bauch TrailSuite 439' '261 Savannah IslandSuite 304'
#  '069 Claire GroveSuite 234' '19 Harrison CrestSuite 331'
#  '8986 Alice IslandApt. 026' '487 Summer MewsApt. 874'
#  '4155 Hughes RidgeApt. 624' '011 Hamilton PlaceSuite 215'
#  '040 Savannah GroveSuite 967' '01 Lee GroveSuite 419'
#  '16 Kuhn LoopSuite 442' '1604 Olivia CrestApt. 164'
#  '394 Lily HillSuite 153' '2684 Tillman ParadeApt. 492'
#  '478 Amy RunSuite 042' '164 Fisher RidgeSuite 516'
#  '2937 Lockman TrackSuite 047' '9484 Amelia View RdApt. 760'
#  '95 Justin PlaceApt. 441' '87 Cruickshank Estate DrApt. 374'
#  '1713 Cormier RunSuite 980' '011 Bosco JunctionSuite 765'
#  '1952 Collins StreetSuite 930' '8227 Nicholas HillSuite 150'
#  '002 Beau PlazaApt. 308' '765 Christiansen ParkwaySuite 557'
#  '473 Leo CourtSuite 784' '62 Jonathan CrestSuite 012'
#  '821 Isabella JunctionApt. 238' '52 Savannah LaneApt. 519'
#  '735 Goldner AvenueSuite 768' '3796 Kayla RoadSuite 477'
#  '150 Nate LoopApt. 614' '88 Olson GroveApt. 120'
#  '42 Mackenzie CourtApt. 934' '163 Sophia RunApt. 833'
#  '2797 Corkery KnollApt. 001' '6308 Amelie MeadowSuite 634'
#  '16 Mitchell RidgeApt. 501' '4317 Holly CourtSuite 716'
#  '865 Patel RoadSuite 457' '35 Fahey CircuitSuite 014'
#  '748 Lucas WayApt. 482' '39 Wilkinson CrestApt. 257'
#  '655 Max TrailSuite 049' '4277 Ryan IslandSuite 792'
#  '63 Tremblay BoulevardApt. 688' '76 Zac KnollSuite 031'
#  '2245 Heathcote RidgeApt. 525' '899 Lynch LaneSuite 349'
#  '00 Willow PlazaApt. 126' '25 Mikayla MewsApt. 558'
#  '515 Grace LaneSuite 974' '533 Archie StreetApt. 007'
#  "82 O'hara LoopSuite 558" '348 Johnston RoadSuite 155'
#  '03 Spencer MewsSuite 726' '385 Jayden View RdApt. 459'
#  '812 Corwin Estate DrSuite 687' '096 Gibson ManorApt. 195'
#  '5538 Jett MallSuite 854' '2724 Madison SummitSuite 567'
#  '96 Daniel PlaceSuite 898' '4715 Hand View RdSuite 955'
#  '4680 Cartwright TrailSuite 706' '384 Hayley View RdSuite 949'
#  '53 Lucy CrescentSuite 222' "806 O'connell CrestApt. 665"
#  '12 Nate RidgeApt. 107' '85 Cooper CrescentApt. 819'
#  "813 O'reilly View RdSuite 466" '9662 Isaac MallSuite 490'
#  '656 Abigail KnollApt. 083' '615 Hayley KnollSuite 454'
#  '3128 Ivy CircleSuite 713' '622 Hamish CourtSuite 367'
#  '62 Mcdermott HillSuite 903' '276 Jade CourtSuite 661'
#  '1189 Hettinger SummitSuite 723' '00 Zachary AvenueApt. 781'
#  '8606 Victoria TerraceSuite 560' '786 Mackenzie StreetApt. 660'
#  '20 Hyatt LaneSuite 740' '49 Klein DriveSuite 199'
#  '42 Michael RoadApt. 405' '80 Hermiston WaySuite 403'
#  '028 Elijah TrailApt. 268' '75 Kovacek KnollSuite 417'
#  '35 Robinson Station StSuite 547' '97 Rowe CrestApt. 828'
#  '8095 Kuhlman StreetApt. 657' '5306 Cody LaneApt. 083'
#  '26 Levi CrestSuite 002' '6369 Patrick HillApt. 508'
#  '2079 Phoebe AvenueSuite 629' '1463 Hills RidgeApt. 034'
#  '5085 Bergstrom MewsApt. 347' '08 Howe BoulevardApt. 286'
#  '107 Xavier MewsApt. 927' '419 Logan CircuitApt. 206'
#  '71 Annabelle RunApt. 053' '93 Anna TerraceSuite 700'
#  "88 D'amore CircleApt. 533" '868 Jonathan TrackApt. 142'
#  '080 Tahlia LaneApt. 450' '60 Claudia LaneSuite 183'
#  "026 D'amore RunSuite 187" '1649 Owen JunctionApt. 523'
#  '31 Towne SummitSuite 671' '91 William IslandSuite 740'
#  '2352 Kutch ParkwayApt. 436' '617 Morrison CrescentSuite 793'
#  '5419 Alyssa AvenueSuite 084' '733 Oliver WaySuite 667'
#  "8982 O'reilly PlazaSuite 007" '6939 Isabelle Station StApt. 204'
#  '9018 Paige WayApt. 282']
# city : 604
# city : ['Sanfordborough' 'Lake Danielland' 'Graceville' 'East Sienna'
#  'New Rileybury' 'East Sophia' 'Lake Jesse' 'Maxberg' 'South Clairetown'
#  'Trompview' 'Lake Alihaven' 'Aidenton' 'Laylabury' 'Huelfort' 'Langfort'
#  'Hermistonside' 'North Matthewfort' 'South Nathan' 'Matthewstad'
#  'Port Isabel' 'South Alexandraview' 'East Jasper' 'Annaton' 'East Piper'
#  'Lake Abigailhaven' 'East Benjamin' 'Mullerberg' 'Thomaschester'
#  'Morissetteborough' 'Port Anna' 'Jademouth' 'Cameronton' 'Turcottetown'
#  'Lincolnbury' 'New Alexchester' 'Josephmouth' 'Blakemouth' 'Thompsonport'
#  'Heaneyview' 'North Aidentown' 'New Beaumouth' 'Miafort' 'North Avabury'
#  'Monahanside' 'Abbottbury' 'Port Aliview' 'Dickensshire' 'Lake Alice'
#  'North Lillian' 'East Imogen' 'Port Sarah' 'Boyerland' 'Lake Lukeberg'
#  'East Max' 'Port Jade' 'Beiermouth' 'West Jonathanshire' 'Port Cody'
#  'Port Lily' 'New Leah' 'East Audrey' 'South Hannahstad' 'Masonfurt'
#  'West Siennaland' 'Port Natalie' 'Harrismouth' 'Port Rosemouth' 'Amyton'
#  'Davidtown' 'Abbottburgh' 'Lewiston' 'West Claudia' 'Port Blake'
#  'Goodwinmouth' 'Port Harrychester' 'Shieldsside' 'Callummouth'
#  'Rodriguezbury' 'South Rileyview' 'North Jessica' 'Elijahburgh'
#  'Port Isabelle' 'Smythland' 'South Emilyborough' 'Stewartland'
#  'Port Annabelle' 'Stantonmouth' 'New Madisonborough' 'Kiehnfurt'
#  'Kohlerberg' 'Sofiaberg' 'Gabriellatown' 'New Chase' 'Haleybury'
#  'North Josephmouth' 'North Scarlettborough' 'West Michaelport'
#  'Port Isabellafurt' 'Cameronport' 'Marcusshire' 'Olivershire'
#  'Port Siennaport' 'Andrewborough' 'New Mayaburgh' 'Hamiltonport'
#  'Shieldschester' 'West Annaton' 'New Ava' 'Lake Rose' 'Jacobport'
#  'West Audreyhaven' 'Port Elliechester' 'South Jayden' 'Beattychester'
#  "O'keefeton" 'Durgantown' 'Connellyport' 'Port Aaronton' 'South Tyler'
#  'Mollyland' 'Lachlanstad' 'South Hannah' 'Fayburgh' 'Hermistonberg'
#  'Abigailshire' 'South Evaport' 'North Justin' 'Isaacberg'
#  'Lake Bellahaven' 'Port Molly' 'New Angelina' 'Hackettland' 'Fadelland'
#  'Tillmanview' 'Stokestown' 'West Chasemouth' 'Andersonburgh'
#  'New Charlieville' "O'connertown" 'Feeneymouth' 'Abbeyshire'
#  'West Phoenix' 'South Anthonyburgh' 'Evansburgh' 'Gleasonburgh'
#  'Claudiaview' 'Georgiatown' 'Lake Declanland' 'East Aidan'
#  'Charlotteville' 'Fadelburgh' 'Audreyport' 'Sarahstad' 'East Madison'
#  'Leofurt' 'North Cody' 'Daughertyport' 'Adamsside' 'Jaydenside'
#  'East Marcus' 'Rubyfort' 'New Emmastad' 'South Adam' 'New Sophie'
#  'New Harry' 'West Thomas' 'Boyleberg' 'South Callum' 'East Isla'
#  'Lake Evemouth' 'Jordanside' 'West Baileyville' 'Baumbachtown'
#  'Walterstad' 'Emilymouth' 'Krisland' 'Cassinport' 'Port Chelseaport'
#  'Madisonland' 'West Aaron' 'Amelieburgh' 'East Chasehaven' 'Gracemouth'
#  'East Michaelmouth' 'Jasmineville' 'Isabellaton' 'West Lukeshire'
#  'Willowmouth' 'Harveyside' 'Reillyfurt' 'Hoppetown' 'Lake Aiden'
#  'North Mikayla' 'Davidfurt' 'Taylorfurt' 'Hettingerfort' 'Gabrielville'
#  'Mayerland' 'Hellermouth' 'Hackettchester' 'Lake Oliverberg'
#  'Hamiltonshire' 'West Kiara' 'East Matthewville' 'Phoebeberg'
#  'Williammouth' 'New Masonport' 'Harberview' 'Port Liam' 'Sophiemouth'
#  'West Noah' 'Kuhntown' 'North Mia' 'Lucyport' 'Conroychester'
#  'Beahanport' 'Kreigerberg' 'West Zoe' 'New Sienna' 'Islamouth'
#  'West Danieltown' 'Laraview' 'Chasemouth' 'Declanton' 'Kulasville'
#  'Eveside' 'East Declanside' 'Lake Amelia' 'Siennabury' 'Johnstonshire'
#  'Baileyberg' 'Port Joeltown' 'Lake Jacobborough' 'South Holly'
#  'Crooksshire' 'Port Davidburgh' 'Chelseaview' 'Angelinaport'
#  'Richardshaven' 'Bauchton' 'North Caitlin' 'Samuelside' 'Youngview'
#  'Port Marcusshire' 'Lake Edward' 'Lake Callumville' 'South Chelseaton'
#  'South Alexview' 'Chloeville' 'Jordanborough' 'New Ruby' 'Jaspermouth'
#  'New Matildaville' 'Johnschester' 'Lake Matildaville' 'New Hannah'
#  'Walterland' 'Port Sebastianland' 'Bayermouth' 'Hicklebury'
#  'East Zacharystad' 'North Ruby' 'Callumborough' 'South Sophieview'
#  'New Jadehaven' 'Kaylafurt' 'Jacobsland' 'New Jackson' 'West Aidenview'
#  'East Xavier' 'Port Adamburgh' 'Hallhaven' 'North Edwardshire'
#  'Macdonaldchester' 'West Isabelton' 'Swiftfort' 'East Mackenzietown'
#  'Carterbury' 'West Lachlan' 'Port Ellaside' 'West Addison'
#  'New Ellieland' 'East Ruby' 'New Isaac' 'East Jakeberg' 'Ameliaview'
#  'Violetborough' 'North Ellabury' 'Oscarberg' 'West Hamish'
#  'Charlotteborough' 'Handborough' 'Lake Paigemouth' 'West Alyssa'
#  'Gardenport' 'Samanthaberg' 'Port Lillianside' 'West Jackfort'
#  'West Luke' 'Port Eveland' 'West Isla' 'West Kai' 'Violetfort'
#  'South Codyhaven' 'North Sebastianberg' 'Port Lucas' 'Hartmannshire'
#  'West Ashley' 'North Marcusland' 'Donnellyfort' 'Thomasborough'
#  'Audreyfurt' 'West John' 'Towneport' 'West Grace' 'Evastad' 'Lake Charli'
#  'West Madison' 'Charlesshire' 'Lake Nicholasfort' 'Walkertown'
#  'South Georgia' 'Davidshire' 'Lake Audreyborough' 'South Claudialand'
#  'Lake Sienna' 'East Mason' 'Hansenberg' 'Angelinaville' 'Thompsonbury'
#  'Michaelfurt' 'Sauerfort' 'South Declan' 'Lake Laurenview' 'Kaiberg'
#  'Lake Phoenixside' 'North Jasperville' 'North Gracetown' 'Harveyville'
#  'Huelhaven' 'Port Madelineberg' 'Hudsontown' 'Levihaven' 'Amberland'
#  'Violetstad' 'West Jessica' 'West Finnberg' 'Port Joshualand'
#  "D'amoreborough" 'Alexanderland' 'Edwardtown' 'Jasperside'
#  'Lake Gabrielview' 'Scottview' 'Ryanfurt' 'North Alex' 'Port Hunter'
#  'Port Ali' 'New Jayden' 'Dietrichville' 'Zacville' 'New Kai'
#  'West Benjaminberg' 'Jordanburgh' 'Hannahberg' 'North Isabelleside'
#  'Lake Addisonland' 'Zacharybury' 'Aliceland' 'Port Ella'
#  'North Sophieland' 'West Justin' 'Chelseahaven' 'Port Alanamouth'
#  'Sebastianbury' 'Port Michael' 'Olsonbury' 'Port Hannahburgh'
#  'Taylorburgh' 'West Sophie' 'Lilystad' 'North Kaylastad' 'Kiehnburgh'
#  'West Rubyland' 'New Masonstad' 'Bartolettiside' 'West Olivertown'
#  'Josephland' 'Lincolnchester' 'Langworthville' 'West Sebastianfort'
#  'South Levi' 'West Cooper' 'Elijahshire' 'North Ivy' 'Beahantown'
#  'Ryanberg' 'Tylershire' 'North Paige' 'Port Madison' 'Lake Nicholasfurt'
#  'Schneiderstad' 'Lake Mollyburgh' 'West Ellaport' 'New Stellastad'
#  'Bergefort' 'East Joshua' 'North Elijahshire' 'New Oliverside' 'Kaiview'
#  'South Logan' 'East Emily' 'West Hayleyhaven' 'Lake Lucas'
#  'Lake Madelineton' 'Imogenmouth' 'Lake Aidan' 'Port Alyssa' 'Doylebury'
#  'Wildermanside' 'Port Christopher' 'Lake Haydenton' 'Lake Mikaylashire'
#  'South Charles' 'Port Chloe' 'Port Lillian' 'East Kaylabury'
#  'New Angelinaberg' 'Spencerborough' 'Mayaview' 'Kreigerbury'
#  'East Lauren' 'Zacharyborough' 'Calebville' 'Barrowschester'
#  'Lake Ashleyhaven' 'Liamton' 'Grimesstad' 'West Annaport' 'Nathanfort'
#  'North Nicholaston' 'Lake Hannah' 'Hudsonberg' 'Lake Michaelbury'
#  'Muellerfurt' 'Blakeborough' 'Kingmouth' 'Sofiahaven' 'Lake Alanafort'
#  'Russelstad' 'West Callumside' 'New Beau' 'Howehaven' 'Michaelberg'
#  'Parisianmouth' 'East Alex' 'Kaifort' 'Ernserland' 'Lake Lincoln'
#  'North Lukeshire' 'West Dylanport' 'Lake Johnchester' 'Lake Lillyville'
#  'Haydentown' 'Port Sophia' 'Kiehnchester' 'New Callumtown' 'New Alyssa'
#  "O'reillychester" 'East Gabriel' 'Johnsonstad' 'West Zoeberg'
#  'Macdonaldtown' 'Port Jettshire' 'Lake Alicefurt' 'Jacobsshire'
#  'East Chelsea' 'Lake Phoebe' 'Joelland' 'North Andrew' 'North Emmashire'
#  'Noahmouth' 'Leomouth' 'Port Jordan' 'Port Haydenchester'
#  'North Lachlanfurt' 'Haydenhaven' 'South Gabriel' 'Port Abigail'
#  'Codyfort' 'Hollyfort' 'New Codyville' 'Alexandraville' 'Pipershire'
#  'East Hayden' 'Baumbachton' 'East George' 'Gleasonport' 'West Bella'
#  'Maddisonmouth' 'Casperfurt' 'Beahanfurt' 'Alexandramouth' 'Lake William'
#  'South Cameron' 'South Ellieburgh' 'Port Claudia' 'Braunhaven'
#  'Hamishview' 'Kiehnstad' 'North Mackenzieborough' 'Ellieshire'
#  'South Jasper' 'West Bailey' 'Lake Elijah' 'East Sofia' 'New Mollystad'
#  'New Benjaminborough' 'Kaihaven' 'Port Kiara' 'Schneiderbury' 'Jettstad'
#  'Cooperbury' 'Sanfordberg' 'West Elliestad' 'West Marcus' 'Eliburgh'
#  'Lake Owenfurt' 'North Beau' 'Kulasmouth' 'Port Joshuaside' 'Ebertfurt'
#  'North Sophie' 'West Lucy' 'Robertstown' 'Joelmouth' 'West Joelmouth'
#  'Monahanberg' 'South Xavierport' 'West Michael' 'New Emilyton'
#  'South Pipermouth' 'Zacshire' 'North Kayla' 'Lukefurt' 'Port Logan'
#  'New George' 'West Alyssaton' 'Samanthatown' 'Georgeland' 'Colestad'
#  'East Lillyville' 'Savannahland' 'West Amber' 'South Eveshire'
#  'Sanfordton' 'Ellashire' 'Port Ashtonhaven' 'Walshland' 'Bartolettifurt'
#  'Joelburgh' 'Hallshire' 'South Tylermouth' 'Justinport' 'Sophiafurt'
#  'Port Zoeborough' 'Samuelland' 'Johnstonhaven' 'Wilsonside'
#  'South Zacmouth' 'Christopherside' 'Harryburgh' 'North Liamfort'
#  'Lake Owen' 'West Cameron' 'North Baileyside' 'North Riley' 'New Callum'
#  'Angelinastad' 'South Hugoberg' 'Gardenchester' 'Laurenview' 'Bauchland'
#  'West Eviebury' 'West Stella' 'Mitchellhaven' 'South Heidi' 'Hoppeville'
#  'South Maxland' 'North Stephanie' 'East Charlesfurt' 'West Aidanton'
#  'Caitlinview' 'Codyview' 'South Tobyton' 'West Mackenzie' 'Reillyborough'
#  'New Aidenfurt' 'Farrellchester' 'Lake Mitchellbury' 'Rutherfordville'
#  'Lake Matilda' 'Andersonchester' 'Lake Gabriella']
# state : 8
# state : ['South Australia' 'Tasmania' 'New South Wales' 'Queensland' 'Victoria'
#  'Northern Territory' 'Australian Capital Territory' 'Western Australia']
# country : 1
# country : ['Australia']
# product_type : 3
# product_type : ['Shirt' 'Jacket' 'Trousers']
# product_name : 35
# product_name : ['Chambray' 'Puffer' 'Oxford Cloth' 'Wool' 'Parka' 'Drawstring' 'Cropped'
#  'Pleated' 'Linen' 'High-Waisted' 'Shearling' 'Mandarin Collar'
#  'Casual Slim Fit' 'Trench Coat' 'Dress' 'Flannel' 'Slim-Fit' 'Bomber'
#  'Relaxed Leg' 'Peacoat' 'Pullover' 'Leather' 'Coach' 'Chinos'
#  'Cuban Collar' 'Henley' 'Denim' 'Polo' 'Joggers' 'Cargo Pants'
#  'Windbreaker' 'Camp Collared' 'Cords' 'Tracksuit Bottoms' 'Cardigan']
# size : 5
# size : ['L' 'S' 'M' 'XS' 'XL']
# colour : 7
# colour : ['orange' 'indigo' 'red' 'blue' 'green' 'violet' 'yellow']
# description : 1233
# description : ['A orange coloured, L sized, Chambray Shirt'
#  'A indigo coloured, S sized, Puffer Jacket'
#  'A red coloured, M sized, Oxford Cloth Shirt' ...
#  'A green coloured, L sized, Tracksuit Bottoms Trousers'
#  'A violet coloured, XL sized, Cardigan Jacket'
#  'A yellow coloured, XS sized, Polo Shirt']

# %%
# convert to datetime format
df['order_date'] = pd.to_datetime(df['order_date'])
df['delivery_date'] = pd.to_datetime(df['delivery_date'])

# %%
# what is the maximum number of days between the order and delivery
df['differance'] = df['delivery_date']- df['order_date']

# %%
df.head()
# Out:
#    order_id  customer_id  payment order_date delivery_date     customer_name  \
# 0         1           64    30811 2021-08-30    2021-09-24  Annabella Devote
# 1       233          996    29939 2021-09-03    2021-09-19    Elvira Sarfati
# 2       924          786    43116 2021-04-04    2021-04-18   Lorine McLugish
# 3         1           64    30811 2021-08-30    2021-09-24  Annabella Devote
# 4        79          236    54340 2021-03-16    2021-03-25    Anders Couvert
#
#         gender  age                  home_address  zip_code  ... total_price  \
# 0  Genderfluid   75     4927 Alice MeadowApt. 960      7787  ...         212
# 1      Agender   59  0433 Armstrong HillSuite 974      7613  ...         318
# 2      Agender   23    145 Abigail SummitApt. 514      4731  ...         212
# 3  Genderfluid   75     4927 Alice MeadowApt. 960      7787  ...         118
# 4   Non-binary   80       64 Phillips RunApt. 722      2752  ...         236
#
#   product_ID product_type  product_name  size  colour  price  quantity_y  \
# 0        218        Shirt      Chambray     L  orange    105          44
# 1        218        Shirt      Chambray     L  orange    105          44
# 2        218        Shirt      Chambray     L  orange    105          44
# 3        481       Jacket        Puffer     S  indigo    110          62
# 4        481       Jacket        Puffer     S  indigo    110          62
#
#                                   description differance
# 0  A orange coloured, L sized, Chambray Shirt    25 days
# 1  A orange coloured, L sized, Chambray Shirt    16 days
# 2  A orange coloured, L sized, Chambray Shirt    14 days
# 3   A indigo coloured, S sized, Puffer Jacket    25 days
# 4   A indigo coloured, S sized, Puffer Jacket     9 days
#
# [5 rows x 27 columns]

# %%
df['differance'].sort_values(ascending=False).head(20)
# Out:
# 3452   27 days
# 152    27 days
# 156    27 days
# 1660   27 days
# 3798   27 days
# 3793   27 days
# 1628   27 days
# 161    27 days
# 474    27 days
# 2607   27 days
# 164    27 days
# 3757   27 days
# 2628   27 days
# 1569   27 days
# 3718   27 days
# 3715   27 days
# 3705   27 days
# 1544   27 days
# 175    27 days
# 3656   27 days
# Name: differance, dtype: timedelta64[ns]

# %%
# extract year , month and day name for order data
df['year_order'] = df['order_date'].dt.year
df['month_order'] = df['order_date'].dt.month
df["day_order"] = df["order_date"].dt.day
df["name_day_order"] = df["order_date"].dt.day_name()

# %%
# extract year , month and day name for delivery data
df['year_delivery'] = df['delivery_date'].dt.year
df['month_delivery'] = df['delivery_date'].dt.month
df["day_delivery"] = df["delivery_date"].dt.day
df["name_day_delivery"] = df["delivery_date"].dt.day_name()

# %%
df.head()
# Out:
#    order_id  customer_id  payment order_date delivery_date     customer_name  \
# 0         1           64    30811 2021-08-30    2021-09-24  Annabella Devote
# 1       233          996    29939 2021-09-03    2021-09-19    Elvira Sarfati
# 2       924          786    43116 2021-04-04    2021-04-18   Lorine McLugish
# 3         1           64    30811 2021-08-30    2021-09-24  Annabella Devote
# 4        79          236    54340 2021-03-16    2021-03-25    Anders Couvert
#
#         gender  age                  home_address  zip_code  ...  \
# 0  Genderfluid   75     4927 Alice MeadowApt. 960      7787  ...
# 1      Agender   59  0433 Armstrong HillSuite 974      7613  ...
# 2      Agender   23    145 Abigail SummitApt. 514      4731  ...
# 3  Genderfluid   75     4927 Alice MeadowApt. 960      7787  ...
# 4   Non-binary   80       64 Phillips RunApt. 722      2752  ...
#
#                                   description differance year_order  \
# 0  A orange coloured, L sized, Chambray Shirt    25 days       2021
# 1  A orange coloured, L sized, Chambray Shirt    16 days       2021
# 2  A orange coloured, L sized, Chambray Shirt    14 days       2021
# 3   A indigo coloured, S sized, Puffer Jacket    25 days       2021
# 4   A indigo coloured, S sized, Puffer Jacket     9 days       2021
#
#    month_order  day_order  name_day_order  year_delivery  month_delivery  \
# 0            8         30          Monday           2021               9
# 1            9          3          Friday           2021               9
# 2            4          4          Sunday           2021               4
# 3            8         30          Monday           2021               9
# 4            3         16         Tuesday           2021               3
#
#    day_delivery name_day_delivery
# 0            24            Friday
# 1            19            Sunday
# 2            18            Sunday
# 3            24            Friday
# 4            25          Thursday
#
# [5 rows x 35 columns]

# %%
# wat is the total money that each gendre spent
df.groupby('gender')[['total_price']].sum().sort_values(by='total_price',ascending = False)
# Out:
#              total_price
# gender
# Female            145404
# Genderfluid       142077
# Male              138988
# Polygender        132548
# Genderqueer       132389
# Non-binary        126201
# Agender           107179
# Bigender          107014

# %%
# what is the most day that get highest income
df.groupby('name_day_order')[['total_price']].sum().sort_values(by='total_price',ascending = False)
# Out:
#                 total_price
# name_day_order
# Sunday               178532
# Tuesday              153443
# Wednesday            152252
# Saturday             139406
# Thursday             139061
# Monday               135692
# Friday               133414

# %%
# what is the highest month that get the highest sales?
df.groupby('month_order')[['total_price']].sum().sort_values(by='total_price',ascending = False)
# Out:
#              total_price
# month_order
# 3                 131364
# 1                 119333
# 7                 116081
# 8                 104565
# 6                 101458
# 4                  97530
# 9                  96526
# 2                  95080
# 5                  85597
# 10                 84266

# %%
# what is the highest state achieve the highest salees
df.groupby(['state'])[['total_price']].sum().sort_values(by='total_price',ascending = False)
# Out:
#                               total_price
# state
# South Australia                    147816
# Queensland                         142062
# New South Wales                    131744
# Australian Capital Territory       130442
# Western Australia                  125430
# Tasmania                           122095
# Victoria                           120357
# Northern Territory                 111854

# %%
# what is the highest state per gender achieve the highest sales
df.groupby(['state','gender'])[['total_price']].sum().sort_values(by='total_price',ascending = False).head(30)
# Out:
#                                           total_price
# state                        gender
# Queensland                   Polygender         28553
# South Australia              Genderqueer        25088
# Victoria                     Male               24626
# Western Australia            Non-binary         24011
# Queensland                   Genderqueer        23791
# Victoria                     Genderfluid        22970
# New South Wales              Genderfluid        22367
# Tasmania                     Non-binary         22281
# New South Wales              Male               22248
# Australian Capital Territory Agender            22052
# South Australia              Male               22043
# Australian Capital Territory Genderfluid        21859
#                              Male               21623
# South Australia              Polygender         21536
# Victoria                     Female             21343
# Tasmania                     Female             21332
# Western Australia            Polygender         21012
# New South Wales              Non-binary         20983
# Queensland                   Genderfluid        20476
# Tasmania                     Genderqueer        20278
# Australian Capital Territory Female             19555
# New South Wales              Female             18452
# South Australia              Female             18352
# Queensland                   Female             17959
# Tasmania                     Bigender           17957
# Northern Territory           Genderqueer        17872
# Western Australia            Genderqueer        16947
#                              Genderfluid        16777
# Queensland                   Male               16768
# South Australia              Bigender           16052

# %%
# what is the average age per state
df.groupby(['state'])[['age']].mean().sort_values(by='age',ascending = False)
# Out:
#                                     age
# state
# New South Wales               53.593509
# Queensland                    51.152838
# Northern Territory            48.882798
# South Australia               48.594708
# Tasmania                      48.187713
# Australian Capital Territory  48.021944
# Western Australia             46.804636
# Victoria                      44.143824

# %%
# what is the average age per state per each gender
df.groupby(['state','gender'])[['age']].mean().sort_values(by='age',ascending = False).head(30)
# Out:
#                                                 age
# state                        gender
# Queensland                   Non-binary   70.405405
# Western Australia            Non-binary   62.254717
# Tasmania                     Genderqueer  60.224490
# New South Wales              Female       58.000000
# Queensland                   Male         57.987342
# New South Wales              Non-binary   57.528846
# South Australia              Bigender     57.070588
# Australian Capital Territory Female       56.666667
# New South Wales              Male         55.685714
# Queensland                   Genderfluid  55.405941
# New South Wales              Bigender     55.267857
#                              Genderqueer  54.660377
# Northern Territory           Non-binary   54.223684
# South Australia              Genderqueer  53.702479
# Queensland                   Bigender     52.631579
# Western Australia            Polygender   51.558824
# South Australia              Non-binary   51.355263
# New South Wales              Polygender   51.225806
# Queensland                   Female       50.819277
# Tasmania                     Polygender   50.652174
# South Australia              Genderfluid  50.562500
# Victoria                     Bigender     50.277778
# Tasmania                     Bigender     49.931818
# Northern Territory           Genderqueer  49.865854
#                              Agender      49.838710
#                              Genderfluid  49.821918
# South Australia              Male         49.777778
# Australian Capital Territory Polygender   49.242424
#                              Bigender     48.934426
# Northern Territory           Polygender   48.627119

# %%
df.product_type.value_counts()
# Out:
# Trousers    1683
# Jacket      1676
# Shirt       1641
# Name: product_type, dtype: int64

# %%
# what is the product type that have the highest sales
df.groupby(['product_type'])[['total_price']].sum().sort_values(by='total_price',ascending = False)
# Out:
#               total_price
# product_type
# Jacket             357026
# Trousers           341174
# Shirt              333600

# %%
# what is the color of the product type that have highest sales?
df.groupby(['colour','product_type'])[['total_price']].sum().sort_values(by='total_price',ascending = False)
# Out:
#                      total_price
# colour product_type
# blue   Jacket              56381
# green  Jacket              55160
# violet Shirt               53583
# blue   Trousers            53392
# indigo Trousers            50487
# yellow Jacket              50451
# red    Jacket              50063
# indigo Jacket              49791
#        Shirt               49161
# violet Jacket              48839
# red    Shirt               48573
# blue   Shirt               48447
# yellow Trousers            48354
# violet Trousers            47538
# orange Trousers            47269
# red    Trousers            47262
# orange Shirt               47147
# green  Trousers            46872
# orange Jacket              46341
# yellow Shirt               45363
# green  Shirt               41326
